# %%
import pandas as pd
import numpy as np
import sys
import codecs
import nltk

df_reviews = pd.read_json ("data/reviews_with_language.json")

# %%
df_reviews1 = df_reviews[df_reviews['Trip_type']!='']
df_reviews1
# Out:
#                                Name           City  Rating  \
# 1      Bed and Breakfast Il Rifugio  Caltanissetta       5
# 3                     Garibaldi R&B        Messina       5
# 4      Bed and Breakfast Il Rifugio  Caltanissetta       5
# 6                     Garibaldi R&B        Messina       5
# 7               Residence La Gancia        Trapani       5
# ...                             ...            ...     ...
# 45342                   Sabbinirica         Ragusa       4
# 45343                   Sabbinirica         Ragusa       5
# 45344                  Itria Palace         Ragusa       4
# 45345                  Itria Palace         Ragusa       5
# 45347                  Itria Palace         Ragusa       5
#
#                                                   Review  Hometown  \
# 1      location molto comoda...Ti permette di postegg...    Italia
# 3      Graziosissimo R&B con vista sullo stretto. Ott...    Italia
# ...

# %%
df_reviews1.loc[df_reviews1['Trip_type'] == ' Ha viaggiato per affari']
# Out:
#                                        Name           City  Rating  \
# 3                             Garibaldi R&B        Messina       5
# 34                            Garibaldi R&B        Messina       5
# 36     Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 99                            Garibaldi R&B        Messina       5
# 104                         A Casa di Amici  Caltanissetta       5
# ...                                     ...            ...     ...
# 45170                  Locanda La Meridiana         Ragusa       5
# 45182                  Locanda La Meridiana         Ragusa       5
# 45183                  Locanda La Meridiana         Ragusa       5
# 45184                  Locanda La Meridiana         Ragusa       5
# 45318                           Sabbinirica         Ragusa       5
#
#                                                   Review Hometown  \
# 3      Graziosissimo R&B con vista sullo stretto. Ott...   Italia
# ...

# %%
df_reviews[df_reviews["City"]=='Catania'].count()
# Out:
# Name            6528
# City            6528
# Rating          6528
# Review          6528
# Hometown        6528
# Date_of_stay    6528
# Trip_type       6528
# geonames_id     6528
# Language        6528
# dtype: int64
