# %%
import pandas as pd
import numpy as np
import sys
import codecs

# %%
df = pd.read_json ("data/reviews_en/it-en.json")

# %%
df.head(35)
# Out:
#     index lang                                             review  \
# 0       1   it  location molto comoda...Ti permette di postegg...
# 1       3   it  Graziosissimo R&B con vista sullo stretto. Ott...
# 2       4   it  Arrivato in questo B&B quasi X caso e cioè gra...
# 3       6   it  Colorato e curato nei minimi dettagli. Le stan...
# 4       7   it  Al centro di Trapani c’è questa bellissima str...
# 5       9   it  durante il ns tour ci siamo fermati per una no...
# 6      12   it  Ho soggiornato per la seconda volta. Una confe...
# 7      15   it  Abbiamo alloggiato qui su consiglio di amici. ...
# 8      17   it  Insieme alla mia famiglia, abbiamo passato una...
# 9      18   it  Bellissima struttura in centro a Trapani, che ...
# 10     21   it  Dopo una dolorosa carcrash abbiamo contattato ...
# 11     23   it  Ottima sistemazione a Messina. Stile anni cinq...
# 12     27   it  B&B sapientemente gestito, a conduzione famili...
# ...

# %%
df['index'][32]
# Out:
# 74

# %%
df.review_en.loc[32]
# Out:
# "We needed one night for the last leg of our trip to southern Italy, before heading to Catania and the airport. We booked this B&B in booking. com arrived at 8:00 am after a long drive from the mainland. What could have been a tiring and confusing urban arrival on a busy night street was made easy enough by Favio, a host who did so much for us that it would have been difficult to do better. We had previously chatted on WhatsApp and it provided us with useful points of reference. (The signage for this place is a small plaque on an otherwise nondescript building - like many B & Bs.) I parked twice as my wife entered. (The road is wide enough to do this - and Italians do it a lot. Favio went out and took some of the luggage. Very friendly and very good English. We checked in quickly and efficiently. Favio offers paid parking ( 10 euros) in a nearby lot but we chose free overnight parking. Favio physically blocked a spot on the road for us near the accommodation while I maneuvered over i
# ...

# %%
annotazione_servizi = pd.read_csv("annotazioni/csv/annotazione_servizi3.csv", delimiter=';',keep_default_na=False)

# %%
annotazione_servizi[annotazione_servizi['lang']=='it']
# Out:
#     index lang                                             review  \
# 62    131   it  After a long search I found this B&B. At first...
# 63    133   it  The stay was fantastic, the room has every com...
# 64    136   it  Great availability from the owner and a beauti...
# 65    137   it  It is well located being only 10 minutes from ...
# 66    139   it  Very nice and comfortable B&B. Rooms furnished...
# 67    141   it  The only thing I didn't like about this B&B is...
# 68    143   it  Very nice b & b, brand new and well furnished....
# 69    145   it  B&B located near the port and convenient to re...
# 70    147   it  Brand new rooms, satisfactory cleaning, brand ...
# 71    149   it  I have been for three days on busy occasions. ...
#
#               amenity_1            amenity_2            amenity_3 amenity_4  \
# 62     air conditioning                 Wifi  Breakfast available
# 63                 Wifi     Air conditioning
# 64
# ...

# %%
servizi_list

# %%
x = df['colonna_recensione']

# %%
s = pd.read_json('annotazioni/annotazione_completa300.json')

# %%
s
# Out:
#      index lang                                             review  \
# 0    35689   da  The hotel is nicely located. Not out on Ortigi...
# 1    36725   da  The only good thing one can say about this hot...
# 2    37909   da  A wonderful little hotel that is very centrall...
# 3    38022   da  This hotel is surrounded by fields. There are ...
# 4    39403   da  This small hotel located in the old town of Si...
# ..     ...  ...                                                ...
# 317  24618   pl  Very nice and clean rooms in the heart of the ...
# 318  24626   pl  The apartment was clean and cleaned basically ...
# 319  24632   pl  A city hotel, very well located, in the heart ...
# 320  24704   pl  I highly recommend this hotel. The apartment i...
# 321  25301   pl  The very good location of this apartment allow...
#
#                               amenity_1                           amenity_2  \
# 0                          Roof terrace                 Breakfast available
# ...

# %%
s[s['lang']=='it'][5:]
# Out:
#      index lang                                             review  \
# 69     145   it  B&B located near the port and convenient to re...
# 70     147   it  Brand new rooms, satisfactory cleaning, brand ...
# 71     149   it  I have been for three days on busy occasions. ...
# 102      3   it  Very nice R&B overlooking the strait. Excellen...
# 103      7   it  In the center of Trapani there is this beautif...
# 104     17   it  Together with my family, we spent one night in...
# 105     31   it  With my girlfriend we decided to visit Messina...
# 106     35   it  Structure located in the historic center of Tr...
# 107     56   it  I only stayed one night at this property and I...
# 108     58   it  We stayed on the banks of the strait staying a...
# 109     61   it  Ideal location for those who, like us, wanted ...
# 110     64   it  Structure easy to find and immersed in the won...
# 111     74   it  We needed one night for the last leg of our tr...
# ...
