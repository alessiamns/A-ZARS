# %%
import pandas as pd
import numpy as np
from langdetect import detect
df_reviews = pd.read_json("data/reviews_with_geo.json")
df_reviews
# Out:
#                                        Name           City  Rating  \
# 0      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 1              Bed and Breakfast Il Rifugio  Caltanissetta       5
# 2      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 3                             Garibaldi R&B        Messina       5
# 4              Bed and Breakfast Il Rifugio  Caltanissetta       5
# ...                                     ...            ...     ...
# 45343                           Sabbinirica         Ragusa       5
# 45344                          Itria Palace         Ragusa       4
# 45345                          Itria Palace         Ragusa       5
# 45346                          Itria Palace         Ragusa       4
# 45347                          Itria Palace         Ragusa       5
#
#                                                   Review     Hometown  \
# 0      Excellent facilities in a spacious luxurious l...  Regno Unito
# 1      location molto comoda...Ti permette di postegg...       Italia
# 2      estuvimos alojados 4 noches y no puedo poner n...       Spagna
# 3      Graziosissimo R&B con vista sullo stretto. Ott...       Italia
# 4      Arrivato in questo B&B quasi X caso e cioè gra...       Italia
# ...                                                  ...          ...
# 45343  It is a very nice hotel. The hotel is very new...     Germania
# 45344  Il mio fidanzato ed io abbiamo pernottato in q...       Italia
# 45345  Partiamo dalla gentilezza e la disponibilità d...       Italia
# 45346  Bellissimo hotel, grande gentilezza e posizion...       Italia
# 45347  Una struttura accogliente con annesso parchegg...       Italia
#
#           Date_of_stay                      Trip_type  geonames_id
# 0       settembre 2019                                     2635167
# 1       settembre 2019         Ha viaggiato con amici      3175395
# 2        febbraio 2020                                     2510769
# 3         gennaio 2020        Ha viaggiato per affari      3175395
# 4          giugno 2019           Ha viaggiato da solo      3175395
# ...                ...                            ...          ...
# 45343    novembre 2017   Ha viaggiato con la famiglia      2921044
# 45344      agosto 2020         Ha viaggiato in coppia      3175395
# 45345      agosto 2020         Ha viaggiato in coppia      3175395
# 45346      luglio 2020                                     3175395
# 45347      agosto 2020         Ha viaggiato in coppia      3175395
#
# [45348 rows x 8 columns]

# %%
df_reviews.insert(8, 'Language', '')

# %%
for i in range(0,len(df_reviews)):
    lang = detect(df_reviews['Review'][i])
    df_reviews.Language.loc[i] = lang
    
df_reviews.to_json('data/reviews_with_language.json')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_language = pd.read_json("data/reviews_with_language.json")
df_language
# Out:
#                                        Name           City  Rating  \
# 0      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 1              Bed and Breakfast Il Rifugio  Caltanissetta       5
# 2      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 3                             Garibaldi R&B        Messina       5
# 4              Bed and Breakfast Il Rifugio  Caltanissetta       5
# ...                                     ...            ...     ...
# 45343                           Sabbinirica         Ragusa       5
# 45344                          Itria Palace         Ragusa       4
# 45345                          Itria Palace         Ragusa       5
# 45346                          Itria Palace         Ragusa       4
# 45347                          Itria Palace         Ragusa       5
#
#                                                   Review     Hometown  \
# 0      Excellent facilities in a spacious luxurious l...  Regno Unito
# 1      location molto comoda...Ti permette di postegg...       Italia
# 2      estuvimos alojados 4 noches y no puedo poner n...       Spagna
# 3      Graziosissimo R&B con vista sullo stretto. Ott...       Italia
# 4      Arrivato in questo B&B quasi X caso e cioè gra...       Italia
# ...                                                  ...          ...
# 45343  It is a very nice hotel. The hotel is very new...     Germania
# 45344  Il mio fidanzato ed io abbiamo pernottato in q...       Italia
# 45345  Partiamo dalla gentilezza e la disponibilità d...       Italia
# 45346  Bellissimo hotel, grande gentilezza e posizion...       Italia
# 45347  Una struttura accogliente con annesso parchegg...       Italia
#
#           Date_of_stay                      Trip_type  geonames_id Language
# 0       settembre 2019                                     2635167       en
# 1       settembre 2019         Ha viaggiato con amici      3175395       it
# 2        febbraio 2020                                     2510769       es
# 3         gennaio 2020        Ha viaggiato per affari      3175395       it
# 4          giugno 2019           Ha viaggiato da solo      3175395       it
# ...                ...                            ...          ...      ...
# 45343    novembre 2017   Ha viaggiato con la famiglia      2921044       en
# 45344      agosto 2020         Ha viaggiato in coppia      3175395       it
# 45345      agosto 2020         Ha viaggiato in coppia      3175395       it
# 45346      luglio 2020                                     3175395       it
# 45347      agosto 2020         Ha viaggiato in coppia      3175395       it
#
# [45348 rows x 9 columns]
