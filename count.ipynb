# %%
import pandas as pd
import numpy as np
import sys
import codecs
import nltk


df_reviews = pd.read_json ("data/reviews.json", lines=True)

# %%
df_reviews
# Out:
#                                        Name           City  Rating  \
# 0      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 1              Bed and Breakfast Il Rifugio  Caltanissetta       5
# 2      Delle Vittorie Luxury Rooms & Suites        Palermo       5
# 3                             Garibaldi R&B        Messina       5
# 4              Bed and Breakfast Il Rifugio  Caltanissetta       5
# ...                                     ...            ...     ...
# 45343                           Sabbinirica         Ragusa       5
# 45344                          Itria Palace         Ragusa       4
# 45345                          Itria Palace         Ragusa       5
# 45346                          Itria Palace         Ragusa       4
# 45347                          Itria Palace         Ragusa       5
#
#                                                   Review     Hometown  \
# 0      Excellent facilities in a spacious luxurious l...  Regno Unito
# ...

# %%
a = df_reviews.loc[df_reviews['City'] == 'Caltanissetta']

# %%
a
# Out:
#                               Name           City  Rating  \
# 1     Bed and Breakfast Il Rifugio  Caltanissetta       5
# 4     Bed and Breakfast Il Rifugio  Caltanissetta       5
# 15    Bed and Breakfast Il Rifugio  Caltanissetta       5
# 21    Bed and Breakfast Il Rifugio  Caltanissetta       5
# 27                     Villa Russo  Caltanissetta       5
# ...                            ...            ...     ...
# 2480                     Casa Rosy  Caltanissetta       5
# 2485      Lussuosamente Luxury B&B  Caltanissetta       5
# 2490            Qal'at Apart Hotel  Caltanissetta       5
# 2492            Qal'at Apart Hotel  Caltanissetta       5
# 2499                 Villa Niscima  Caltanissetta       5
#
#                                                  Review     Hometown  \
# 1     location molto comoda...Ti permette di postegg...       Italia
# 4     Arrivato in questo B&B quasi X caso e cioè gra...       Italia
# ...

# %%
df_amenities = pd.read_json("data/amenities.json", lines=True)
all_amenities = df_amenities.Amenity.unique()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-d1f2dcb7e1a4> in <module>
# ----> 1 all_amenities.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'
